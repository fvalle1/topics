# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !python3 -m pip install watermark
# %load_ext watermark
# %watermark -v -m  -u -n -p pandas,numpy,seaborn,tensorflow,matplotlib -a Filippo_Valle -g -r -b -w
# Out:
# Collecting watermark
#   Downloading https://files.pythonhosted.org/packages/60/fe/3ed83b6122e70dce6fe269dfd763103c333f168bf91037add73ea4fe81c2/watermark-2.0.2-py2.py3-none-any.whl
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from watermark) (5.5.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython->watermark) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->watermark) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython->watermark) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->watermark) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython->watermark) (2.1.3)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython->watermark) (4.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->watermark) (49.1.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython->watermark) (4.4.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->watermark) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->watermark) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython->watermark) (0.6.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython->watermark) (0.2.0)
# Installing collected packages: watermark
# Successfully installed watermark-2.0.2
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Filippo_Valle
# last updated: Wed Jul 22 2020
#
# CPython 3.6.9
# IPython 5.5.0
#
# pandas 1.0.5
# numpy 1.18.5
# seaborn 0.10.1
# tensorflow 2.2.0
# matplotlib 3.2.2
#
# compiler   : GCC 8.4.0
# system     : Linux
# release    : 4.19.104+
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 2
# interpreter: 64bit
# Git hash   :
# Git repo   :
# Git branch :
# watermark 2.0.2

# %%
import pandas as pd
import numpy as np
import os,sys, gc
import matplotlib.pyplot as plt
# !pip install --extra-index https://test.pypi.org/simple pandarallel topicpy
from topicpy.hsbmpy import get_max_available_L

os.environ["TF_CUDNN_USE_AUTOTUNE"]="0" #to avoid Nvidia GPU warming up

# %%
algorithm = "topsbm"
directory='/content/drive/My Drive/phd/datasets/merged'
L = get_max_available_L(directory, algorithm)-2
os.chdir(directory)

# %%
label = 'primary_site'

df_topics = pd.read_csv("%s/%s_level_%d_topic-dist.csv"%(algorithm,algorithm,L)).set_index('doc').drop('i_doc', axis=1)
df_words = pd.read_csv("%s/%s_level_%d_word-dist.csv"%(algorithm,algorithm,L), index_col=0)
df_words.index=[g[:15] for g in df_words.index]
df = pd.read_csv("mainTable.csv", index_col=0).reindex(index=df_words.index)
df = df.divide(df.sum(0),1).transpose().fillna(0)
df_files=pd.read_csv("files.dat", index_col=0)
df_topics.insert(0,'tissue', df_files.reindex(index=df_topics.index)[label])
df_topic_tissue = df_topics.groupby('tissue').mean()
df_files.head()
# Out:
#                              primary_site   status dataset        tissue_hd
# TCGA-E8-A2JQ-11A-11R-A180-07      Thyroid  healthy    tcga  Thyroid_healthy
# TCGA-EL-A3ZK-11A-11R-A23N-07      Thyroid  healthy    tcga  Thyroid_healthy
# TCGA-BJ-A28X-11A-11R-A22L-07      Thyroid  healthy    tcga  Thyroid_healthy
# TCGA-BJ-A28R-11A-11R-A16R-07      Thyroid  healthy    tcga  Thyroid_healthy
# TCGA-EL-A3T8-11A-11R-A22L-07      Thyroid  healthy    tcga  Thyroid_healthy

# %% [markdown]
# ## Predictor

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import binary_crossentropy,mean_squared_error, categorical_crossentropy
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import plot_model,to_categorical
from tensorflow.keras.callbacks import Callback, CSVLogger, EarlyStopping
from tensorflow.keras.models import load_model
from tensorflow.keras import backend as K
from tensorflow.python.client.device_lib import list_local_devices
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
import os,sys, gc
list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14822310022525574449, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 16184543443724773245
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 4581106114089589078
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11150726272
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1240821656283076295
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
df_labels=df_files.copy()
df_labels=df_labels.reindex(index=df_topics.index)

uniq = len(df_labels[label].unique())

X_train = df_topics.drop('tissue',1)
X_train = X_train.subtract(X_train.mean(0),1).divide(0.5*(X_train.max(0)-X_train.min(0)),1).values.astype(float) #SGD transform
Y_train = to_categorical(np.unique(df_labels[label], return_inverse=True)[1])
inputs = X_train.shape[1]

if uniq==2: #hidden=(1941,100), bs=50 
  Y_train = np.argmax(Y_train, axis=-1)
  uniq = 1
  activation_func = "sigmoid"
  lr = 0.01
  bs = 50
  momentum = 0.9
  l1 = 0.01
  l2 = 0.0001
  loss=binary_crossentropy
else: #hidden (1941,100), bs=500, l1=0.001, l2=1e-9
  activation_func = "softmax"
  lr = 0.03
  bs = 500
  momentum = 0.95
  l1 = 0.001
  l2 = 1e-9
  loss=categorical_crossentropy


classes=np.unique(df_labels[df_labels.index.isin(df.index)][label], return_inverse=True)[0]

X_tm_train, X_tm_test, Y_tm_train, Y_tm_test = train_test_split(X_train, Y_train, random_state=42, train_size=0.95)

print(uniq, X_train.shape, Y_train.shape, X_tm_train.shape, Y_tm_train.shape)
# Out:
# 8 (800, 1941) (800, 8) (760, 1941) (760, 8)

# %% [markdown]
# # K-NN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, roc_auc_score

class KNNClassifier(KNeighborsClassifier):
    def __init__(self, n_neighbors=10, **kwargs):
        super().__init__(n_neighbors, **kwargs)

    def fit(self,  X, y):
        return super().fit(X, y)

    def evaluate(self, X, Y):
        Y_pred = self.predict(X)
        if tf.cast(tf.round(tf.reduce_max(Y)),tf.int64) > tf.constant(1, dtype=tf.int64):
            Y = to_categorical(Y)
            Y_pred = to_categorical(Y_pred)
        acc = accuracy_score(Y, Y_pred)
        auc = roc_auc_score(Y, Y_pred, average="weighted", multi_class="ovr")
        print(f"Accuracy: {acc}, AUC:{auc}")
        return [acc, auc]

def fit_knn(X_knn_train, X_knn_test, Y_knn_train, Y_knn_test):
    X_pj_train, X_pj_test, Y_pj_train, Y_pj_test = list(map(tf.convert_to_tensor, (X_knn_train, X_knn_test, Y_knn_train, Y_knn_test)))
    print(uniq, X_knn_train.shape, Y_knn_train.shape, X_knn_test.shape, Y_knn_test.shape, Y_knn_train[0])
    import time
    with tf.device("GPU"):
        model_knn = KNNClassifier(n_neighbors=5, n_jobs=4, metric="euclidean")
        model_knn.fit(X_knn_train, Y_knn_train)
        model_knn.evaluate(X_knn_test, Y_knn_test)

X_knn_train, X_knn_test, Y_knn_train, Y_knn_test = train_test_split(df.values, np.unique(df_files.reindex(index=df.index)[label], return_inverse=True)[1], random_state=42, train_size=0.8)
fit_knn(X_knn_train, X_knn_test, Y_knn_train, Y_knn_test)

X_knn_train, X_knn_test, Y_knn_train, Y_knn_test = train_test_split(pd.read_csv("mainTable.csv", index_col=0).reindex(index=df_words.index).fillna(0).applymap(lambda tpm: np.log2(tpm+1)).values.T, np.unique(df_files.reindex(index=df.index)[label], return_inverse=True)[1], random_state=42, train_size=0.8)
fit_knn(X_knn_train, X_knn_test, Y_knn_train, Y_knn_test)

X_knn_train, X_knn_test, Y_knn_train, Y_knn_test = train_test_split(X_train, Y_train, random_state=42, train_size=0.8)
fit_knn(X_knn_train, X_knn_test, Y_knn_train, Y_knn_test)

model_knn = KNNClassifier(n_neighbors=5, n_jobs=4, metric="euclidean")
model_knn.fit(X_knn_train, Y_knn_train)
model_knn.evaluate(X_knn_test, Y_knn_test)
# Out:
# 8 (640, 3000) (640,) (160, 3000) (160,) 3
# Accuracy: 0.725, AUC:0.8452846625797257
# 8 (640, 3000) (640,) (160, 3000) (160,) 3
# Accuracy: 0.96875, AUC:0.9825230949250535
# 8 (640, 1941) (640, 8) (160, 1941) (160, 8) [0. 0. 0. 1. 0. 0. 0. 0.]
# Accuracy: 0.95, AUC:0.9726779925711956
# Accuracy: 0.95, AUC:0.9726779925711956
# [0.95, 0.9726779925711956]

# %% [markdown]
# # Neural Net

# %%
K.clear_session()

os.system("rm -rf log.csv")
csv_logger = CSVLogger('log.csv', append=True, separator=',')
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, mode='min', patience=25)

model=Sequential()
model.add(Dense(units=100, input_dim=inputs, use_bias=True, bias_initializer="ones", activation="relu", kernel_regularizer=l1_l2(l1=l1, l2=l2)))
model.add(Dense(units=uniq, activation=activation_func))
model.compile(loss=loss, optimizer=SGD(lr=lr, momentum=momentum), metrics=['accuracy', 'AUC'])
K.set_learning_phase(0)

print(model.summary())
plot_model(model, to_file=f"model_{label}.png", dpi=600, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               194200
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 808
# =================================================================
# Total params: 195,008
# Trainable params: 195,008
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
with tf.device("GPU"):
    model.fit(X_tm_train, Y_tm_train, epochs=1000, batch_size=bs, verbose=1, validation_split=0.25, callbacks=[csv_logger, es], shuffle=True, use_multiprocessing=True, workers=-1)
# Out:
# Epoch 1/1000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2/2 [==============================] - 0s 218ms/step - loss: 7.8507 - accuracy: 0.1316 - auc: 0.4759 - val_loss: 7.2660 - val_accuracy: 0.1842 - val_auc: 0.6199
# Epoch 2/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 7.2286 - accuracy: 0.2596 - auc: 0.6437 - val_loss: 6.8498 - val_accuracy: 0.5105 - val_auc: 0.7951
# Epoch 3/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 6.7838 - accuracy: 0.5211 - auc: 0.8196 - val_loss: 6.4731 - val_accuracy: 0.4947 - val_auc: 0.8711
# Epoch 4/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 6.3301 - accuracy: 0.5789 - auc: 0.9071 - val_loss: 5.8341 - val_accuracy: 0.8421 - val_auc: 0.9809
# Epoch 5/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 5.7385 - accuracy: 0.8737 - auc: 0.9903 - val_loss: 5.5506 - val_accuracy: 0.9000 - val_auc: 0.9948
# Epoch 6/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 5.5042 - accuracy: 0.9140 - auc: 0.9936 - val_loss: 5.3661 - val_accuracy: 0.9263 - val_auc: 0.9951
# Epoch 7/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 5.3268 - accuracy: 0.9386 - auc: 0.9948 - val_loss: 5.1615 - val_accuracy: 0.9474 - val_auc: 0.9977
# Epoch 8/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 5.1230 - accuracy: 0.9491 - auc: 0.9972 - val_loss: 5.0053 - val_accuracy: 0.9579 - val_auc: 0.9986
# Epoch 9/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 4.9604 - accuracy: 0.9632 - auc: 0.9976 - val_loss: 4.8999 - val_accuracy: 0.9526 - val_auc: 0.9984
# Epoch 10/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 4.8406 - accuracy: 0.9684 - auc: 0.9977 - val_loss: 4.8093 - val_accuracy: 0.9368 - val_auc: 0.9978
# Epoch 11/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.7338 - accuracy: 0.9684 - auc: 0.9979 - val_loss: 4.7108 - val_accuracy: 0.9421 - val_auc: 0.9974
# Epoch 12/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.6199 - accuracy: 0.9719 - auc: 0.9981 - val_loss: 4.5956 - val_accuracy: 0.9474 - val_auc: 0.9976
# Epoch 13/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.5001 - accuracy: 0.9789 - auc: 0.9983 - val_loss: 4.4729 - val_accuracy: 0.9579 - val_auc: 0.9978
# Epoch 14/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 4.3771 - accuracy: 0.9842 - auc: 0.9985 - val_loss: 4.3502 - val_accuracy: 0.9632 - val_auc: 0.9981
# Epoch 15/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 4.2535 - accuracy: 0.9825 - auc: 0.9987 - val_loss: 4.2272 - val_accuracy: 0.9632 - val_auc: 0.9959
# Epoch 16/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 4.1286 - accuracy: 0.9825 - auc: 0.9996 - val_loss: 4.1022 - val_accuracy: 0.9684 - val_auc: 0.9961
# Epoch 17/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0027 - accuracy: 0.9877 - auc: 0.9997 - val_loss: 3.9756 - val_accuracy: 0.9684 - val_auc: 0.9962
# Epoch 18/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.8751 - accuracy: 0.9912 - auc: 0.9998 - val_loss: 3.8477 - val_accuracy: 0.9632 - val_auc: 0.9963
# Epoch 19/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.7461 - accuracy: 0.9930 - auc: 0.9999 - val_loss: 3.7182 - val_accuracy: 0.9632 - val_auc: 0.9964
# Epoch 20/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.6179 - accuracy: 0.9930 - auc: 0.9999 - val_loss: 3.5883 - val_accuracy: 0.9684 - val_auc: 0.9964
# Epoch 21/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.4888 - accuracy: 0.9947 - auc: 1.0000 - val_loss: 3.4596 - val_accuracy: 0.9684 - val_auc: 0.9965
# Epoch 22/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.3597 - accuracy: 0.9947 - auc: 1.0000 - val_loss: 3.3320 - val_accuracy: 0.9684 - val_auc: 0.9965
# Epoch 23/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.2314 - accuracy: 0.9947 - auc: 1.0000 - val_loss: 3.2057 - val_accuracy: 0.9684 - val_auc: 0.9965
# Epoch 24/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.1037 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 3.0813 - val_accuracy: 0.9632 - val_auc: 0.9965
# Epoch 25/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 2.9775 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 2.9593 - val_accuracy: 0.9579 - val_auc: 0.9965
# Epoch 26/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 2.8526 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 2.8390 - val_accuracy: 0.9632 - val_auc: 0.9964
# Epoch 27/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.7293 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 2.7186 - val_accuracy: 0.9632 - val_auc: 0.9964
# Epoch 28/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 2.6076 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 2.5986 - val_accuracy: 0.9632 - val_auc: 0.9988
# Epoch 29/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 2.4878 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 2.4786 - val_accuracy: 0.9632 - val_auc: 0.9989
# Epoch 30/1000
# 2/2 [==============================] - 0s 36ms/step - loss: 2.3701 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 2.3581 - val_accuracy: 0.9632 - val_auc: 0.9989
# Epoch 31/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 2.2546 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 2.2386 - val_accuracy: 0.9684 - val_auc: 0.9991
# Epoch 32/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 2.1416 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 2.1220 - val_accuracy: 0.9684 - val_auc: 0.9992
# Epoch 33/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 2.0319 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 2.0088 - val_accuracy: 0.9684 - val_auc: 0.9993
# Epoch 34/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 1.9258 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 1.9000 - val_accuracy: 0.9737 - val_auc: 0.9994
# Epoch 35/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 1.8238 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 1.7969 - val_accuracy: 0.9737 - val_auc: 0.9995
# Epoch 36/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 1.7259 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 1.6994 - val_accuracy: 0.9842 - val_auc: 0.9996
# Epoch 37/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 1.6321 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 1.6075 - val_accuracy: 0.9842 - val_auc: 0.9996
# Epoch 38/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 1.5426 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 1.5208 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 39/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 1.4568 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 1.4394 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 40/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 1.3750 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 1.3633 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 41/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 1.2976 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 1.2922 - val_accuracy: 0.9684 - val_auc: 0.9997
# Epoch 42/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2251 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 1.2256 - val_accuracy: 0.9684 - val_auc: 0.9996
# Epoch 43/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 1.1574 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 1.1632 - val_accuracy: 0.9684 - val_auc: 0.9996
# Epoch 44/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 1.0941 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 1.1054 - val_accuracy: 0.9684 - val_auc: 0.9996
# Epoch 45/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 1.0353 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 1.0518 - val_accuracy: 0.9684 - val_auc: 0.9996
# Epoch 46/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.9806 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 1.0020 - val_accuracy: 0.9684 - val_auc: 0.9996
# Epoch 47/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.9300 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.9568 - val_accuracy: 0.9684 - val_auc: 0.9996
# Epoch 48/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.8838 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.9159 - val_accuracy: 0.9684 - val_auc: 0.9996
# Epoch 49/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8425 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.8792 - val_accuracy: 0.9684 - val_auc: 0.9996
# Epoch 50/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.8050 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.8460 - val_accuracy: 0.9789 - val_auc: 0.9996
# Epoch 51/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.7711 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.8168 - val_accuracy: 0.9789 - val_auc: 0.9996
# Epoch 52/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7404 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.7925 - val_accuracy: 0.9737 - val_auc: 0.9995
# Epoch 53/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.7129 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.7717 - val_accuracy: 0.9737 - val_auc: 0.9995
# Epoch 54/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6882 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.7524 - val_accuracy: 0.9737 - val_auc: 0.9994
# Epoch 55/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6660 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.7341 - val_accuracy: 0.9684 - val_auc: 0.9992
# Epoch 56/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6458 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.7167 - val_accuracy: 0.9579 - val_auc: 0.9991
# Epoch 57/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6273 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.6952 - val_accuracy: 0.9632 - val_auc: 0.9992
# Epoch 58/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6083 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.6714 - val_accuracy: 0.9684 - val_auc: 0.9995
# Epoch 59/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5901 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.6503 - val_accuracy: 0.9737 - val_auc: 0.9996
# Epoch 60/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5738 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.6324 - val_accuracy: 0.9737 - val_auc: 0.9997
# Epoch 61/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5587 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.6159 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 62/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5438 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.6004 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 63/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5290 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.5854 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 64/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5145 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.5726 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 65/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5008 - accuracy: 0.9947 - auc: 1.0000 - val_loss: 0.5626 - val_accuracy: 0.9684 - val_auc: 0.9996
# Epoch 66/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4884 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.5545 - val_accuracy: 0.9632 - val_auc: 0.9995
# Epoch 67/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4769 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.5459 - val_accuracy: 0.9684 - val_auc: 0.9994
# Epoch 68/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4658 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.5370 - val_accuracy: 0.9684 - val_auc: 0.9993
# Epoch 69/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4558 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.5274 - val_accuracy: 0.9737 - val_auc: 0.9994
# Epoch 70/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4469 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.5139 - val_accuracy: 0.9737 - val_auc: 0.9995
# Epoch 71/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4377 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.4980 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 72/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4274 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.4842 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 73/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4179 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.4752 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 74/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4101 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.4692 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 75/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4031 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.4657 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 76/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3963 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.4637 - val_accuracy: 0.9684 - val_auc: 0.9996
# Epoch 77/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3890 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.4594 - val_accuracy: 0.9684 - val_auc: 0.9995
# Epoch 78/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3813 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.4502 - val_accuracy: 0.9737 - val_auc: 0.9996
# Epoch 79/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3738 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.4401 - val_accuracy: 0.9737 - val_auc: 0.9997
# Epoch 80/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3674 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.4309 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 81/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3621 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.4228 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 82/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3561 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.4148 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 83/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3492 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.4092 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 84/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3439 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.4061 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 85/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3402 - accuracy: 0.9947 - auc: 1.0000 - val_loss: 0.4028 - val_accuracy: 0.9737 - val_auc: 0.9997
# Epoch 86/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3365 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3981 - val_accuracy: 0.9737 - val_auc: 0.9997
# Epoch 87/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3311 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3915 - val_accuracy: 0.9737 - val_auc: 0.9997
# Epoch 88/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3252 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3866 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 89/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3206 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3837 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 90/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3176 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.3811 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 91/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3141 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3782 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 92/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3101 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3745 - val_accuracy: 0.9737 - val_auc: 0.9997
# Epoch 93/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3065 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3695 - val_accuracy: 0.9737 - val_auc: 0.9997
# Epoch 94/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3033 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3636 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 95/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2997 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3584 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 96/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2963 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3541 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 97/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2932 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3508 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 98/1000
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2901 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3482 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 99/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2873 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3466 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 100/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2849 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.3454 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 101/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2826 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3441 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 102/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2800 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3433 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 103/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2777 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3423 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 104/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2759 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3408 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 105/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2740 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3382 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 106/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2717 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3347 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 107/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2692 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3302 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 108/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2667 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3267 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 109/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2647 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3243 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 110/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2626 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3230 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 111/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2606 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3219 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 112/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2590 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3214 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 113/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2574 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3205 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 114/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2553 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3186 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 115/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2538 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3161 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 116/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2526 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3140 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 117/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2510 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 118/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2494 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3116 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 119/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2480 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3120 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 120/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2468 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3120 - val_accuracy: 0.9737 - val_auc: 0.9997
# Epoch 121/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2455 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3105 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 122/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2433 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3097 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 123/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2432 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.3105 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 124/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2445 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.3091 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 125/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2420 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.3084 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 126/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2399 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.3095 - val_accuracy: 0.9737 - val_auc: 0.9997
# Epoch 127/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2401 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3083 - val_accuracy: 0.9737 - val_auc: 0.9997
# Epoch 128/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2398 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3054 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 129/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2383 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.3020 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 130/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2363 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.2981 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 131/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2345 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2950 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 132/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2326 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2929 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 133/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2310 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2906 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 134/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2298 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2884 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 135/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2288 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2862 - val_accuracy: 0.9842 - val_auc: 0.9999
# Epoch 136/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2280 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2842 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 137/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2268 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2832 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 138/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2254 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2834 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 139/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2246 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2849 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 140/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2238 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2870 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 141/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2228 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2886 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 142/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2220 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2882 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 143/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2210 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2875 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 144/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2201 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 145/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2193 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2853 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 146/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2183 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2858 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 147/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2181 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2863 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 148/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2171 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2851 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 149/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2161 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2838 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 150/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2151 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2833 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 151/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2141 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2828 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 152/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2133 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2817 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 153/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2127 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2791 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 154/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2117 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2763 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 155/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2113 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2743 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 156/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2105 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2732 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 157/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2097 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2729 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 158/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2093 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2721 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 159/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2088 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2714 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 160/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2084 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2707 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 161/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2072 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2700 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 162/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2069 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2706 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 163/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2061 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2720 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 164/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2053 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2731 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 165/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2045 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2725 - val_accuracy: 0.9737 - val_auc: 0.9997
# Epoch 166/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2038 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2707 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 167/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2029 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2690 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 168/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2021 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2682 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 169/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2015 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2664 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 170/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2006 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 171/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1998 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2626 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 172/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1989 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2617 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 173/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1981 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2613 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 174/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1975 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2599 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 175/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1970 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 176/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1963 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2584 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 177/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1957 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2583 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 178/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1950 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2582 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 179/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1944 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2577 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 180/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1939 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 181/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1936 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2572 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 182/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1930 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 183/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1923 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2579 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 184/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1917 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 185/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1914 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2591 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 186/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1909 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2578 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 187/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1904 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 188/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1901 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2551 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 189/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1895 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2554 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 190/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1888 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9737 - val_auc: 0.9998
# Epoch 191/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1885 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2574 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 192/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1882 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2569 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 193/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1876 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2555 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 194/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1872 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2548 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 195/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1866 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2537 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 196/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1863 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2514 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 197/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1858 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2491 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 198/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1852 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2472 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 199/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1846 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2462 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 200/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1840 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2461 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 201/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1836 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2467 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 202/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1832 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2476 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 203/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1827 - accuracy: 0.9982 - auc: 1.0000 - val_loss: 0.2478 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 204/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1821 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2472 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 205/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1814 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2467 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 206/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1807 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2466 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 207/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1803 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2461 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 208/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1799 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2451 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 209/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1795 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2448 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 210/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1791 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2435 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 211/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1782 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2418 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 212/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1780 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2412 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 213/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1781 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2405 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 214/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1776 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2399 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 215/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1769 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2394 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 216/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1764 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2398 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 217/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1763 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2402 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 218/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1761 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2400 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 219/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1755 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2395 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 220/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1747 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2392 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 221/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1743 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2390 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 222/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1739 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2392 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 223/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1735 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2398 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 224/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1731 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2393 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 225/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1727 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2378 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 226/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1721 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2371 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 227/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1720 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2371 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 228/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1717 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2363 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 229/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1712 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2354 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 230/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1708 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2341 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 231/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1704 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2326 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 232/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1701 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 233/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1695 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9842 - val_auc: 0.9999
# Epoch 234/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1690 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2317 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 235/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1685 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2320 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 236/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1680 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 237/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1677 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2320 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 238/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1673 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 239/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1669 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2296 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 240/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1668 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2300 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 241/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1668 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2311 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 242/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1666 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 243/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1661 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2314 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 244/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1655 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2317 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 245/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1651 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2321 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 246/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1648 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2310 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 247/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1643 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2293 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 248/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1641 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 249/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1641 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 250/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1642 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2274 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 251/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1638 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2263 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 252/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1634 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2254 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 253/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1628 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2259 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 254/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1623 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2283 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 255/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1622 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2302 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 256/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1621 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2291 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 257/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1618 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2279 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 258/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1612 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2272 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 259/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1610 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 260/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1608 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 261/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1604 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2279 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 262/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1601 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2274 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 263/1000
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1598 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2263 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 264/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1594 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2250 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 265/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1590 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2239 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 266/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1585 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2237 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 267/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1582 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 268/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1579 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 269/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1574 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2212 - val_accuracy: 0.9842 - val_auc: 0.9999
# Epoch 270/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1573 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2210 - val_accuracy: 0.9789 - val_auc: 0.9999
# Epoch 271/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1571 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2216 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 272/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1566 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 273/1000
# ...
# Epoch 345/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1390 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 346/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1386 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 347/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1386 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 348/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1386 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 349/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1386 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 350/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1384 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 351/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1381 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 352/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1376 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 353/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1374 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 354/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1372 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 355/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1372 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2067 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 356/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1370 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2069 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 357/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1368 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 358/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1365 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 359/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1363 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 360/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1360 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 361/1000
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1359 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 362/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1355 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2047 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 363/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1351 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 364/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1349 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 365/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1345 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2064 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 366/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1344 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 367/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1343 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 368/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1341 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 369/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1339 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 370/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1340 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 371/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1336 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2034 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 372/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1334 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2026 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 373/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1332 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 374/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1329 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 375/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1327 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 376/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1326 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 377/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1324 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2022 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 378/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1322 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 379/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1321 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2002 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 380/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1318 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 381/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1318 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 382/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1321 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2029 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 383/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1319 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 384/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1319 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 385/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1318 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 386/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1316 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 387/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1313 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2019 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 388/1000
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1313 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 389/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1311 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2022 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 390/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1308 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 391/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1304 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 392/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1303 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 393/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1301 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.9789 - val_auc: 0.9997
# Epoch 394/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1298 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2015 - val_accuracy: 0.9789 - val_auc: 0.9998
# Epoch 395/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1297 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 396/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1295 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 397/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1295 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 398/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1293 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 399/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1290 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2018 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 400/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1288 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 401/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1286 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2018 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 402/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1285 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 403/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1284 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 404/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1283 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 405/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1281 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 406/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1279 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1967 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 407/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1277 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 408/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1275 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1940 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 409/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1272 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1928 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 410/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1272 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1928 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 411/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1270 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1947 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 412/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1272 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1968 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 413/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1270 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 414/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1267 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 415/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1267 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1980 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 416/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1265 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 417/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1262 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1960 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 418/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1261 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1955 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 419/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1259 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1960 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 420/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1258 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 421/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1258 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 422/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1256 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 423/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1252 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 424/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1250 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1953 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 425/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1248 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1965 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 426/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1246 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 427/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1244 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 428/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1243 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1967 - val_accuracy: 0.9842 - val_auc: 0.9997
# Epoch 429/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1241 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1947 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 430/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1240 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 431/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1239 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1931 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 432/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1238 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 433/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1237 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1942 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 434/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1236 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1943 - val_accuracy: 0.9842 - val_auc: 0.9998
# Epoch 435/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1235 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9842 - val_auc: 0.9998

# %%
pd.read_csv("log.csv", sep=",")[['loss','val_loss']].plot()

# %%
model.evaluate(X_tm_test, Y_tm_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1794 - accuracy: 1.0000 - auc: 1.0000
# [0.17938263714313507, 1.0, 1.0]

# %%
#model.save(f"model_{label}.h5")
model = load_model(f"model_{label}.h5")
print(model.summary())
#plot_model(model, to_file=f"model_{label}.png", dpi=600, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               194200
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 808
# =================================================================
# Total params: 195,008
# Trainable params: 195,008
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 0

# %% [markdown]
# # evaluate on non used on topsbm training

# %%
df_test_table = pd.read_csv("mainTable_test.csv", index_col = 0)
df_test_table = df_test_table.where(df_test_table<1e5,1e5)

# %%
#project only HV genes
df_topic_test = df_test_table.reindex(index=df_words.index)
df_topic_test = df_topic_test.transpose().fillna(-1).astype(int)

df_topic_test = pd.DataFrame(data=np.matmul(df_topic_test.values,df_words.values), index=df_topic_test.index, columns=df_words.columns)
df_test=df_topic_test.divide(df_topic_test.mean(axis=0), axis=1) #normalize P(t|d)

df_test = df_test.subtract(df_topics.drop("tissue",1).mean(0),1).divide((X_train.max(0)-X_train.min(0)),1) #SGD transform

# %%
classes = np.unique(df_files.reindex(index=df_test.index)[label])
X_test = df_test.values.astype(float)
Y_test = to_categorical([np.where(classes==t)[0][0] for t in df_files.reindex(index=df_test.index)[label].values.ravel()])
if uniq==1:
  Y_test = np.argmax(Y_test, axis=-1)
  uniq=1
#np.savetxt("classes.txt", classes, fmt="%s")
#np.savetxt("X_test.txt", X_test)
#np.savetxt("Y_test.txt", Y_test)

# %%
with tf.device("GPU"):
    model.evaluate(X_test, Y_test, verbose=2, workers=-1, use_multiprocessing=True)
    if uniq ==1:
        model_knn.evaluate(tf.convert_to_tensor(df_topic_test), tf.convert_to_tensor(Y_test))
    else:
        model_knn.evaluate(tf.convert_to_tensor(df_topic_test), tf.convert_to_tensor(Y_test))
# Out:
# 161/161 - 1s - loss: 0.6207 - accuracy: 0.9273 - auc: 0.9852
# Accuracy: 0.8203079321769635, AUC:0.9023049505093931

# %%
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
import seaborn as sns

# %%
y_pred_p = model.predict(X_test)
if uniq>1:
  y_true = np.argmax(Y_test,axis=-1)
  y_pred = np.argmax(y_pred_p,axis=-1)
else:
  y_pred_p = y_pred_p.ravel()
  y_true = Y_test
  y_pred = np.ones(y_pred_p.shape)
  y_pred[y_pred_p<0.5]=0
results = confusion_matrix(y_true, y_pred, normalize="true")

# %%
cm = sns.clustermap(results, 
                    vmax=1,  
                    row_cluster=False, 
                    col_cluster=False, 
                    xticklabels=classes, 
                    yticklabels=classes, 
                    annot=False,
                    annot_kws={"fontsize":15},
                    cbar_pos=(0.99,0.05,0.05,0.7))
ax = cm.ax_heatmap
fig = ax.get_figure()
ax.set_ylabel("real", fontsize=35, rotation=90)
ax.set_yticklabels(labels=classes, rotation=0)
ax.yaxis.tick_left()
ax.yaxis.set_label_position("left")

ax.set_xticklabels(labels=classes, rotation=80)
ax.set_xlabel("predicted",fontsize=35)
ax.tick_params(labelsize=35)

cax = cm.ax_cbar
cax.tick_params(labelsize=30)
cax.set_title("P()", fontsize=30)
plt.tight_layout()
cm.savefig(f"predict_{label}.pdf")

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
